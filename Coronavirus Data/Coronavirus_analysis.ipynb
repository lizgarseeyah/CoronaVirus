# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %% [markdown]
# ## Viewing the data

# %%
full_data = pd.read_csv("/Users/lizgarcia/Desktop/Coronavirus_Data/full_data.csv")
full_data.head(10)
# Out:
#          date     location  new_cases  new_deaths  total_cases  total_deaths
# 0  2020-02-25  Afghanistan        NaN         NaN            1           NaN
# 1  2020-02-26  Afghanistan        0.0         NaN            1           NaN
# 2  2020-02-27  Afghanistan        0.0         NaN            1           NaN
# 3  2020-02-28  Afghanistan        0.0         NaN            1           NaN
# 4  2020-02-29  Afghanistan        0.0         NaN            1           NaN
# 5  2020-03-01  Afghanistan        0.0         NaN            1           NaN
# 6  2020-03-02  Afghanistan        0.0         NaN            1           NaN
# 7  2020-03-03  Afghanistan        0.0         NaN            1           NaN
# 8  2020-03-04  Afghanistan        0.0         NaN            1           NaN
# 9  2020-03-05  Afghanistan        0.0         NaN            1           NaN

# %%
data.shape
# Out:
# (53, 126)

# %%
new_cases = pd.read_csv("/Users/lizgarcia/Desktop/Coronavirus_Data/new_cases.csv")
new_cases.head()
# Out:
#          date  Worldwide  Afghanistan  Albania  Algeria  Andorra  Argentina  \
# 0  2020-01-21          0          NaN      NaN      NaN      NaN        NaN
# 1  2020-01-22         32          NaN      NaN      NaN      NaN        NaN
# 2  2020-01-23        266          NaN      NaN      NaN      NaN        NaN
# 3  2020-01-24        262          NaN      NaN      NaN      NaN        NaN
# 4  2020-01-25        467          NaN      NaN      NaN      NaN        NaN
#
#    Armenia  Australia  Austria  ...  Thailand  Togo  Tunisia  Turkey  Ukraine  \
# 0      NaN        NaN      NaN  ...       NaN   NaN      NaN     NaN      NaN
# 1      NaN        NaN      NaN  ...       0.0   NaN      NaN     NaN      NaN
# 2      NaN        NaN      NaN  ...       2.0   NaN      NaN     NaN      NaN
# 3      NaN        NaN      NaN  ...       0.0   NaN      NaN     NaN      NaN
# 4      NaN        NaN      NaN  ...       0.0   NaN      NaN     NaN      NaN
#
# ...

# %%
new_deaths = pd.read_csv("/Users/lizgarcia/Desktop/Coronavirus_Data/new_deaths.csv")
new_deaths.head()
# Out:
#          date  Worldwide  Afghanistan  Albania  Algeria  Andorra  Argentina  \
# 0  2020-01-21          0          NaN      NaN      NaN      NaN        NaN
# 1  2020-01-22          0          NaN      NaN      NaN      NaN        NaN
# 2  2020-01-23         11          NaN      NaN      NaN      NaN        NaN
# 3  2020-01-24          8          NaN      NaN      NaN      NaN        NaN
# 4  2020-01-25         16          NaN      NaN      NaN      NaN        NaN
#
#    Armenia  Australia  Austria  ...  Thailand  Togo  Tunisia  Turkey  Ukraine  \
# 0      NaN        NaN      NaN  ...       NaN   NaN      NaN     NaN      NaN
# 1      NaN        NaN      NaN  ...       NaN   NaN      NaN     NaN      NaN
# 2      NaN        NaN      NaN  ...       NaN   NaN      NaN     NaN      NaN
# 3      NaN        NaN      NaN  ...       NaN   NaN      NaN     NaN      NaN
# 4      NaN        NaN      NaN  ...       NaN   NaN      NaN     NaN      NaN
#
# ...

# %%
total_cases = pd.read_csv("/Users/lizgarcia/Desktop/Coronavirus_Data/total_cases.csv")
total_cases.head()
# Out:
#          date  Worldwide  Afghanistan  Albania  Algeria  Andorra  Argentina  \
# 0  2020-01-21        282          NaN      NaN      NaN      NaN        NaN
# 1  2020-01-22        314          NaN      NaN      NaN      NaN        NaN
# 2  2020-01-23        581          NaN      NaN      NaN      NaN        NaN
# 3  2020-01-24        846          NaN      NaN      NaN      NaN        NaN
# 4  2020-01-25       1320          NaN      NaN      NaN      NaN        NaN
#
#    Armenia  Australia  Austria  ...  Thailand  Togo  Tunisia  Turkey  Ukraine  \
# 0      NaN        NaN      NaN  ...         2   NaN      NaN     NaN      NaN
# 1      NaN        NaN      NaN  ...         2   NaN      NaN     NaN      NaN
# 2      NaN        NaN      NaN  ...         4   NaN      NaN     NaN      NaN
# 3      NaN        NaN      NaN  ...         4   NaN      NaN     NaN      NaN
# 4      NaN        3.0      NaN  ...         4   NaN      NaN     NaN      NaN
#
# ...

# %%
total_deaths = pd.read_csv("/Users/lizgarcia/Desktop/Coronavirus_Data/total_deaths.csv")
total_deaths.head()
# Out:
#          date  Worldwide  Afghanistan  Albania  Algeria  Andorra  Argentina  \
# 0  2020-01-21          6          NaN      NaN      NaN      NaN        NaN
# 1  2020-01-22          6          NaN      NaN      NaN      NaN        NaN
# 2  2020-01-23         17          NaN      NaN      NaN      NaN        NaN
# 3  2020-01-24         25          NaN      NaN      NaN      NaN        NaN
# 4  2020-01-25         41          NaN      NaN      NaN      NaN        NaN
#
#    Armenia  Australia  Austria  ...  Thailand  Togo  Tunisia  Turkey  Ukraine  \
# 0      NaN        NaN      NaN  ...       NaN   NaN      NaN     NaN      NaN
# 1      NaN        NaN      NaN  ...       NaN   NaN      NaN     NaN      NaN
# 2      NaN        NaN      NaN  ...       NaN   NaN      NaN     NaN      NaN
# 3      NaN        NaN      NaN  ...       NaN   NaN      NaN     NaN      NaN
# 4      NaN        NaN      NaN  ...       NaN   NaN      NaN     NaN      NaN
#
# ...

# %%
# assessing for missing data
pd.options.display.max_rows = None
full_data.shape[0] - full_data.count()
# Out:
# date               0
# location           0
# new_cases        124
# new_deaths      1888
# total_cases        0
# total_deaths    1855
# dtype: int64

# %%
# Investigate patterns in the amount of missing data in each column.

na_count=pd.DataFrame(data.shape[0] - data.count())
na_count.columns=['na_count']
plt.hist(na_count['na_count'])
# Out:
# (array([  3.,   0.,   1.,   0.,   1.,   4.,   1.,   2.,   6., 108.]),
#  array([ 0. ,  5.3, 10.6, 15.9, 21.2, 26.5, 31.8, 37.1, 42.4, 47.7, 53. ]),
#  <a list of 10 Patch objects>)
